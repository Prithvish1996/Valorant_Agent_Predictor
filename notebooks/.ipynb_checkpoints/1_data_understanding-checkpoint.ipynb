# %% [markdown]
# # Data Understanding
# In this stage CRISP-DM, we will explore the datasets to understand their structure, content, and quality. This involves examining the columns, data types, and sample records to get a sense of what information is available. We will also check for missing values, identify any anomalies such as negative numbers or future dates, and generate statistical summaries of key features. By visualizing patterns and spotting anomalies, we try to gain insights into gameplay trends and data quality issues that may impact our analysis in later stages.
#
# For more details on each step, please refer to the Data Understanding documentation at `../docs/1_data_understanding.md`

# %% [markdown]
# ## Step 1: Import Libraries and Load Dataset
# The first step in the data understanding phase is to load the datasets and get a sense of their structure and content. This involves examining the columns, data types, and sample records to understand what information is available and how it can be used for analysis.

# %% [markdown]
# 1A. Set up project paths and import necessary libraries

# %%
# ── Step 1A: Import Libraries ─────────────────────────────────────────────
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

PROJECT_ROOT = Path().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.data.data_loader import DataLoader
from src.utils.anomalies import (
    find_inconsistent_outcomes,
    numeric_anomaly_summary,
)
from src.utils.data_viz_utils import (
    plot_categorical_bottom,
    plot_numeric_box,
)
from src.utils.display_utils import display_side_by_side

# %% [markdown]
# 1B. Setting up the data directory path

# %%
# ── Step 1B: Set up Data Paths ────────────────────────────────────────────
DATA_DIR    = PROJECT_ROOT / "data" / "external"
INTERIM_DIR = PROJECT_ROOT / "data" / "interim"

# %% [markdown]
# 1C. Loading the datasets and displaying them side by side for a quick overview

# %%
# ── Step 1C: Load Datasets ────────────────────────────────────────────────
data_loader    = DataLoader(DATA_DIR)
agent_role_df  = data_loader.load_data("agent_master_list.csv")
player_game_df = data_loader.load_data("valorant_games_messy.csv")

display_side_by_side(
    agent_role_df,
    player_game_df,
    titles=["Agent Role", "Player Game"],
    rows=5
)

# Merge to add role column from agent master list
# Using left join to keep all player records, missing agents will have empty role
player_game_df = pd.merge(
    player_game_df, 
    agent_role_df[['Agent', 'Role']], 
    left_on='agent', 
    right_on='Agent', 
    how='left'
)

# Drop redundant Agent column after merge, keep role column
player_game_df = player_game_df.drop(columns=['Agent'])
# Rename Role to role for consistency
player_game_df = player_game_df.rename(columns={'Role': 'role'})

print(f"\nMerged dataset shape: {player_game_df.shape}")
print(f"Added 'role' column. Missing agents will have NaN in role column.")

print("Final Dataset Sample:")
display(player_game_df.head(10).style.background_gradient(cmap='Reds').format(precision=2))

# write data to processed folder for next steps
INTERIM_DIR.mkdir(parents=True, exist_ok=True)
player_game_df.to_csv(INTERIM_DIR / "player_game_data.csv", index=False)
# Out:
#     <div style="display:flex; gap:30px; align-items:flex-start;">
#
#         <div>
#             <h4 style='margin-bottom:8px'>Agent Role</h4>
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Agent</th>
#       <th>Role</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Jett</td>
#       <td>Duelist</td>
#     </tr>
#     <tr>
#       <td>Phoenix</td>
#       <td>Duelist</td>
#     </tr>
#     <tr>
#       <td>Reyna</td>
#       <td>Duelist</td>
#     </tr>
#     <tr>
#       <td>Raze</td>
#       <td>Duelist</td>
#     </tr>
#     <tr>
#       <td>Yoru</td>
#       <td>Duelist</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#
#         <div>
#             <h4 style='margin-bottom:8px'>Player Game</h4>
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>game_id</th>
#       <th>episode</th>
#       <th>act</th>
#       <th>rank</th>
#       <th>date</th>
#       <th>agent</th>
#       <th>map</th>
#       <th>outcome</th>
#       <th>round_wins</th>
#       <th>round_losses</th>
#       <th>kills</th>
#       <th>deaths</th>
#       <th>assists</th>
#       <th>kdr</th>
#       <th>avg_dmg_delta</th>
#       <th>headshot_pct</th>
#       <th>avg_dmg</th>
#       <th>acs</th>
#       <th>num_frag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6</td>
#       <td>2</td>
#       <td>Placement</td>
#       <td>4/11/2023</td>
#       <td>Cypher</td>
#       <td>Ascent</td>
#       <td>Loss</td>
#       <td>5</td>
#       <td>13</td>
#       <td>8</td>
#       <td>15</td>
#       <td>4</td>
#       <td>0.5</td>
#       <td>-61</td>
#       <td>3</td>
#       <td>76</td>
#       <td>125</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6</td>
#       <td>2</td>
#       <td>Placement</td>
#       <td>4/12/2023</td>
#       <td>Cypher</td>
#       <td>Icebox</td>
#       <td>Loss</td>
#       <td>4</td>
#       <td>13</td>
#       <td>3</td>
#       <td>15</td>
#       <td>2</td>
#       <td>0.2</td>
#       <td>-124</td>
#       <td>22</td>
#       <td>42</td>
#       <td>59</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6</td>
#       <td>2</td>
#       <td>Placement</td>
#       <td>4/15/2023</td>
#       <td>KAY/O</td>
#       <td>Lotus</td>
#       <td>Win</td>
#       <td>13</td>
#       <td>4</td>
#       <td>7</td>
#       <td>12</td>
#       <td>7</td>
#       <td>0.6</td>
#       <td>-46</td>
#       <td>2</td>
#       <td>87</td>
#       <td>132</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6</td>
#       <td>2</td>
#       <td>Placement</td>
#       <td>4/15/2023</td>
#       <td>Brimstone</td>
#       <td>Ascent</td>
#       <td>Loss</td>
#       <td>9</td>
#       <td>13</td>
#       <td>18</td>
#       <td>12</td>
#       <td>10</td>
#       <td>1.5</td>
#       <td>23</td>
#       <td>14</td>
#       <td>137</td>
#       <td>230</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6</td>
#       <td>2</td>
#       <td>Placement</td>
#       <td>4/15/2023</td>
#       <td>Cypher</td>
#       <td>Haven</td>
#       <td>Loss</td>
#       <td>1</td>
#       <td>13</td>
#       <td>6</td>
#       <td>14</td>
#       <td>3</td>
#       <td>0.4</td>
#       <td>-75</td>
#       <td>7</td>
#       <td>90</td>
#       <td>146</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#
#     </div>
# Merged dataset shape: (1296, 20)
# Added 'role' column. Missing agents will have NaN in role column.
# Final Dataset Sample:
# <style type="text/css">
# #T_6f86c_row0_col0, #T_6f86c_row0_col1, #T_6f86c_row0_col2, #T_6f86c_row1_col1, #T_6f86c_row1_col2, #T_6f86c_row1_col10, #T_6f86c_row1_col12, #T_6f86c_row1_col13, #T_6f86c_row1_col14, #T_6f86c_row1_col16, #T_6f86c_row1_col17, #T_6f86c_row2_col1, #T_6f86c_row2_col2, #T_6f86c_row2_col9, #T_6f86c_row2_col15, #T_6f86c_row3_col1, #T_6f86c_row3_col2, #T_6f86c_row3_col18, #T_6f86c_row4_col1, #T_6f86c_row4_col2, #T_6f86c_row4_col8, #T_6f86c_row5_col1, #T_6f86c_row5_col2, #T_6f86c_row6_col1, #T_6f86c_row6_col2, #T_6f86c_row7_col1, #T_6f86c_row7_col2, #T_6f86c_row8_col1, #T_6f86c_row8_col2, #T_6f86c_row9_col1, #T_6f86c_row9_col2, #T_6f86c_row9_col9, #T_6f86c_row9_col11, #T_6f86c_row9_col18 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6f86c_row0_col8, #T_6f86c_row0_col10, #T_6f86c_row0_col18, #T_6f86c_row3_col0, #T_6f86c_row5_col18, #T_6f86c_row7_col10 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_6f86c_row0_col9, #T_6f86c_row1_col9, #T_6f86c_row1_col15, #T_6f86c_row1_col18, #T_6f86c_row2_col8, #T_6f86c_row2_col18, #T_6f86c_row3_col9, #T_6f86c_row3_col10, #T_6f86c_row4_col9, #T_6f86c_row5_col8, #T_6f86c_row5_col12, #T_6f86c_row6_col9, #T_6f86c_row7_col9, #T_6f86c_row7_col18, #T_6f86c_row8_col9, #T_6f86c_row8_col11, #T_6f86c_row9_col0, #T_6f86c_row9_col8, #T_6f86c_row9_col13, #T_6f86c_row9_col14, #T_6f86c_row9_col16, #T_6f86c_row9_col17 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6f86c_row0_col11, #T_6f86c_row1_col11, #T_6f86c_row5_col11, #T_6f86c_row6_col11, #T_6f86c_row7_col11 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_6f86c_row0_col12, #T_6f86c_row7_col12, #T_6f86c_row8_col12 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_6f86c_row0_col13, #T_6f86c_row6_col13, #T_6f86c_row7_col13 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_6f86c_row0_col14, #T_6f86c_row2_col10, #T_6f86c_row2_col16, #T_6f86c_row6_col10, #T_6f86c_row7_col17 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_6f86c_row0_col15, #T_6f86c_row7_col15 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_6f86c_row0_col16, #T_6f86c_row4_col10 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_6f86c_row0_col17 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_6f86c_row1_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_6f86c_row1_col8, #T_6f86c_row4_col15, #T_6f86c_row7_col8, #T_6f86c_row9_col12 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_6f86c_row2_col0 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_6f86c_row2_col11, #T_6f86c_row3_col11, #T_6f86c_row3_col12 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_6f86c_row2_col12 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_6f86c_row2_col13, #T_6f86c_row6_col12 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_6f86c_row2_col14 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_6f86c_row2_col17 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_6f86c_row3_col8, #T_6f86c_row4_col18, #T_6f86c_row5_col9, #T_6f86c_row6_col0, #T_6f86c_row6_col18, #T_6f86c_row8_col18 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_6f86c_row3_col13 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_6f86c_row3_col14 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_6f86c_row3_col15 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_6f86c_row3_col16 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_6f86c_row3_col17 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_6f86c_row4_col0 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_6f86c_row4_col11 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_6f86c_row4_col12 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_6f86c_row4_col13 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_6f86c_row4_col14 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_6f86c_row4_col16 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_6f86c_row4_col17 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_6f86c_row5_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_6f86c_row5_col10, #T_6f86c_row9_col10 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_6f86c_row5_col13 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_6f86c_row5_col14 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_6f86c_row5_col15 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_6f86c_row5_col16 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_6f86c_row5_col17, #T_6f86c_row7_col0 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_6f86c_row6_col8 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_6f86c_row6_col14 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_6f86c_row6_col15 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_6f86c_row6_col16 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_6f86c_row6_col17 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_6f86c_row7_col14 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_6f86c_row7_col16 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_6f86c_row8_col0 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_6f86c_row8_col8 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_6f86c_row8_col10 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_6f86c_row8_col13 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_6f86c_row8_col14 {
#   background-color: #fc8d6d;
#   color: #f1f1f1;
# }
# #T_6f86c_row8_col15 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_6f86c_row8_col16 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_6f86c_row8_col17 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_6f86c_row9_col15 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# </style>
# <table id="T_6f86c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f86c_level0_col0" class="col_heading level0 col0" >game_id</th>
#       <th id="T_6f86c_level0_col1" class="col_heading level0 col1" >episode</th>
#       <th id="T_6f86c_level0_col2" class="col_heading level0 col2" >act</th>
#       <th id="T_6f86c_level0_col3" class="col_heading level0 col3" >rank</th>
#       <th id="T_6f86c_level0_col4" class="col_heading level0 col4" >date</th>
#       <th id="T_6f86c_level0_col5" class="col_heading level0 col5" >agent</th>
#       <th id="T_6f86c_level0_col6" class="col_heading level0 col6" >map</th>
#       <th id="T_6f86c_level0_col7" class="col_heading level0 col7" >outcome</th>
#       <th id="T_6f86c_level0_col8" class="col_heading level0 col8" >round_wins</th>
#       <th id="T_6f86c_level0_col9" class="col_heading level0 col9" >round_losses</th>
#       <th id="T_6f86c_level0_col10" class="col_heading level0 col10" >kills</th>
#       <th id="T_6f86c_level0_col11" class="col_heading level0 col11" >deaths</th>
#       <th id="T_6f86c_level0_col12" class="col_heading level0 col12" >assists</th>
#       <th id="T_6f86c_level0_col13" class="col_heading level0 col13" >kdr</th>
#       <th id="T_6f86c_level0_col14" class="col_heading level0 col14" >avg_dmg_delta</th>
#       <th id="T_6f86c_level0_col15" class="col_heading level0 col15" >headshot_pct</th>
#       <th id="T_6f86c_level0_col16" class="col_heading level0 col16" >avg_dmg</th>
#       <th id="T_6f86c_level0_col17" class="col_heading level0 col17" >acs</th>
#       <th id="T_6f86c_level0_col18" class="col_heading level0 col18" >num_frag</th>
#       <th id="T_6f86c_level0_col19" class="col_heading level0 col19" >role</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f86c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f86c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6f86c_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_6f86c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_6f86c_row0_col3" class="data row0 col3" >Placement</td>
#       <td id="T_6f86c_row0_col4" class="data row0 col4" >4/11/2023</td>
#       <td id="T_6f86c_row0_col5" class="data row0 col5" >Cypher</td>
#       <td id="T_6f86c_row0_col6" class="data row0 col6" >Ascent</td>
#       <td id="T_6f86c_row0_col7" class="data row0 col7" >Loss</td>
#       <

# %% [markdown]
# ## Step 2:
# The second step in the Data Understanding phase is to perform Exploratory Data Analysis (EDA) on our Valorant Player datasets. This involves examining the distributions of key variables such as agents, maps, ranks, and performance statistics, as well as identifying missing values, negative numbers, future dates, or unknown agents. By visualizing patterns, spotting anomalies, and understanding relationships between features like agent choice, map, and match outcomes, EDA provides insights into gameplay trends and data quality issues.

# %% [markdown]
# 2A.  Inspect Data Structure and Samples : Examine the shape, columns and data types to understand what information is available.

# %%
# ── Step 2A: Inspect Data Structure ──────────────────────────────────────
# Displaying the shape of the DataFrames to understand the number of records and features
print("Agent Role DataFrame shape:", agent_role_df.shape)
print("Player Game DataFrame shape:", player_game_df.shape)

print("Data Description: \n")
display(player_game_df.describe().style.background_gradient(cmap='Reds').format(precision=2))
# Out:
# Agent Role DataFrame shape: (26, 2)
# Player Game DataFrame shape: (1296, 20)
# Data Description:
# <style type="text/css">
# #T_0f8ca_row0_col0 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_0f8ca_row0_col1, #T_0f8ca_row0_col2, #T_0f8ca_row0_col3, #T_0f8ca_row0_col4, #T_0f8ca_row0_col5, #T_0f8ca_row0_col6, #T_0f8ca_row0_col7, #T_0f8ca_row0_col8, #T_0f8ca_row0_col9, #T_0f8ca_row0_col10, #T_0f8ca_row0_col11, #T_0f8ca_row0_col12, #T_0f8ca_row0_col13, #T_0f8ca_row7_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0f8ca_row1_col0 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_0f8ca_row1_col1, #T_0f8ca_row2_col3, #T_0f8ca_row2_col4, #T_0f8ca_row2_col5, #T_0f8ca_row2_col6, #T_0f8ca_row4_col1, #T_0f8ca_row4_col3, #T_0f8ca_row4_col4, #T_0f8ca_row5_col1, #T_0f8ca_row6_col1, #T_0f8ca_row6_col7, #T_0f8ca_row7_col1, #T_0f8ca_row7_col13 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_0f8ca_row1_col2, #T_0f8ca_row1_col7, #T_0f8ca_row1_col8, #T_0f8ca_row1_col13, #T_0f8ca_row2_col1, #T_0f8ca_row2_col2, #T_0f8ca_row2_col7, #T_0f8ca_row2_col8, #T_0f8ca_row2_col13, #T_0f8ca_row3_col0, #T_0f8ca_row3_col1, #T_0f8ca_row3_col2, #T_0f8ca_row3_col3, #T_0f8ca_row3_col4, #T_0f8ca_row3_col5, #T_0f8ca_row3_col6, #T_0f8ca_row3_col7, #T_0f8ca_row3_col8, #T_0f8ca_row3_col9, #T_0f8ca_row3_col10, #T_0f8ca_row3_col11, #T_0f8ca_row3_col12, #T_0f8ca_row3_col13, #T_0f8ca_row4_col2, #T_0f8ca_row4_col7, #T_0f8ca_row4_col8, #T_0f8ca_row4_col13, #T_0f8ca_row5_col2, #T_0f8ca_row5_col7, #T_0f8ca_row5_col8, #T_0f8ca_row5_col13, #T_0f8ca_row6_col2, #T_0f8ca_row6_col8, #T_0f8ca_row6_col13, #T_0f8ca_row7_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_0f8ca_row1_col3, #T_0f8ca_row1_col4, #T_0f8ca_row4_col5, #T_0f8ca_row4_col6, #T_0f8ca_row5_col3, #T_0f8ca_row5_col4, #T_0f8ca_row6_col3, #T_0f8ca_row6_col4, #T_0f8ca_row7_col8 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_0f8ca_row1_col5, #T_0f8ca_row1_col6, #T_0f8ca_row4_col10, #T_0f8ca_row5_col5, #T_0f8ca_row5_col6, #T_0f8ca_row6_col6, #T_0f8ca_row7_col3, #T_0f8ca_row7_col7 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_0f8ca_row1_col9, #T_0f8ca_row5_col9 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_0f8ca_row1_col10, #T_0f8ca_row7_col6 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_0f8ca_row1_col11, #T_0f8ca_row5_col11 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_0f8ca_row1_col12 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_0f8ca_row2_col0 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_0f8ca_row2_col9 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_0f8ca_row2_col10, #T_0f8ca_row5_col10, #T_0f8ca_row6_col5, #T_0f8ca_row7_col4 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_0f8ca_row2_col11 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_0f8ca_row2_col12 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_0f8ca_row4_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_0f8ca_row4_col9 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_0f8ca_row4_col11 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_0f8ca_row4_col12 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_0f8ca_row5_col0 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_0f8ca_row5_col12 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_0f8ca_row6_col0 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_0f8ca_row6_col9 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_0f8ca_row6_col10 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_0f8ca_row6_col11 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_0f8ca_row6_col12 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_0f8ca_row7_col5 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_0f8ca_row7_col9 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_0f8ca_row7_col10 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_0f8ca_row7_col11 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_0f8ca_row7_col12 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f8ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f8ca_level0_col0" class="col_heading level0 col0" >game_id</th>
#       <th id="T_0f8ca_level0_col1" class="col_heading level0 col1" >episode</th>
#       <th id="T_0f8ca_level0_col2" class="col_heading level0 col2" >act</th>
#       <th id="T_0f8ca_level0_col3" class="col_heading level0 col3" >round_wins</th>
#       <th id="T_0f8ca_level0_col4" class="col_heading level0 col4" >round_losses</th>
#       <th id="T_0f8ca_level0_col5" class="col_heading level0 col5" >kills</th>
#       <th id="T_0f8ca_level0_col6" class="col_heading level0 col6" >deaths</th>
#       <th id="T_0f8ca_level0_col7" class="col_heading level0 col7" >assists</th>
#       <th id="T_0f8ca_level0_col8" class="col_heading level0 col8" >kdr</th>
#       <th id="T_0f8ca_level0_col9" class="col_heading level0 col9" >avg_dmg_delta</th>
#       <th id="T_0f8ca_level0_col10" class="col_heading level0 col10" >headshot_pct</th>
#       <th id="T_0f8ca_level0_col11" class="col_heading level0 col11" >avg_dmg</th>
#       <th id="T_0f8ca_level0_col12" class="col_heading level0 col12" >acs</th>
#       <th id="T_0f8ca_level0_col13" class="col_heading level0 col13" >num_frag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f8ca_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_0f8ca_row0_col0" class="data row0 col0" >1296.00</td>
#       <td id="T_0f8ca_row0_col1" class="data row0 col1" >1296.00</td>
#       <td id="T_0f8ca_row0_col2" class="data row0 col2" >1296.00</td>
#       <td id="T_0f8ca_row0_col3" class="data row0 col3" >1296.00</td>
#       <td id="T_0f8ca_row0_col4" class="data row0 col4" >1296.00</td>
#       <td id="T_0f8ca_row0_col5" class="data row0 col5" >1296.00</td>
#       <td id="T_0f8ca_row0_col6" class="data row0 col6" >1296.00</td>
#       <td id="T_0f8ca_row0_col7" class="data row0 col7" >1296.00</td>
#       <td id="T_0f8ca_row0_col8" class="data row0 col8" >1296.00</td>
#       <td id="T_0f8ca_row0_col9" class="data row0 col9" >1296.00</td>
#       <td id="T_0f8ca_row0_col10" class="data row0 col10" >1296.00</td>
#       <td id="T_0f8ca_row0_col11" class="data row0 col11" >1296.00</td>
#       <td id="T_0f8ca_row0_col12" class="data row0 col12" >1296.00</td>
#       <td id="T_0f8ca_row0_col13" class="data row0 col13" >1296.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f8ca_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_0f8ca_row1_col0" class="data row1 col0" >734.48</td>
#       <td id="T_0f8ca_row1_col1" class="data row1 col1" >7.49</td>
#       <td id="T_0f8ca_row1_col2" class="data row1 col2" >2.06</td>
#       <td id="T_0f8ca_row1_col3" class="data row1 col3" >9.70</td>
#       <td id="T_0f8ca_row1_col4" class="data row1 col4" >9.58</td>
#       <td id="T_0f8ca_row1_col5" class="data row1 col5" >13.65</td>
#       <td id="T_0f8ca_row1_col6" class="data row1 col6" >12.95</td>
#       <td id="T_0f8ca_row1_col7" class="data row1 col7" >4.79</td>
#       <td id="T_0f8ca_row1_col8" class="data row1 col8" >1.14</td>
#       <td id="T_0f8ca_row1_col9" class="data row1 col9" >7.16</td>
#       <td id="T_0f8ca_row1_col10" class="data row1 col10" >29.93</td>
#       <td id="T_0f8ca_row1_col11" class="data row1 col11" >132.53</td>
#       <td id="T_0f8ca_row1_col12" class="data row1 col12" >192.07</td>
#       <td id="T_0f8ca_row1_col13" class="data row1 col13" >3.45</td>
#     </tr>
#     <tr>
#       <th id="T_0f8ca_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_0f8ca_row2_col0" class="data row2 col0" >518.69</td>
#       <td id="T_0f8ca_row2_col1" class="data row2 col1" >1.10</td>
#       <td id="T_0f8ca_row2_col2" class="data row2 col2" >0.86</td>
#       <td id="T_0f8ca_row2_col3" class="data row2 col3" >4.26</td>
#       <td id="T_0f8ca_row2_col4" class="data row2 col4" >4.31</td>
#       <td id="T_0f8ca_row2_col5" class="data row2 col5" >6.44</td>
#       <td id="T_0f8ca_row2_col6" class="data row2 col6" >5.20</td>
#       <td id="T_0f8ca_row2_col7" class="data row2 col7" >2.78</td>
#       <td id="T_0f8ca_row2_col8" class="data row2 col8" >0.71</td>

# %% [markdown]
# 2B.  Identify Missing Values : Check for any missing values in the datasets and understand their potential impact on analysis.

# %%
# ── Step 2B: Identify Missing Values ─────────────────────────────────────
# Calculating the number of missing values in each column of the player_game_df DataFrame
# Reason: if there are missing values, it can affect the analysis and may require imputation of records, we wont be dropping any records as we want to preserve as much data as possible.
missing_counts = player_game_df.isnull().sum()
missing_percent = (missing_counts / len(player_game_df) * 100).round(2)
missing_df = pd.DataFrame({"Missing Count": missing_counts, "Missing %": missing_percent})
missing_df = missing_df[missing_df["Missing Count"] > 0]

print("Missing values per column:")
display(missing_df)
# Out:
# Missing values per column:
#          Missing Count  Missing %
# rank                15       1.16
# outcome            102       7.87
# role                25       1.93

# %% [markdown]
# Step 2C: Detect Invalid or Anomalous Values: Check for any negative numbers, future dates, or unknown agents that may indicate data quality issues.

# %%
# ── Step 2C: Detect Anomalous Values (Numeric) ────────────────────────────
# Detect columns
numeric_cols = player_game_df.select_dtypes(include=['int64', 'float64']).columns.tolist()

print("Numeric columns:", numeric_cols)


# Dropdowns
dropdown_numeric = widgets.Dropdown(
    options=numeric_cols,
    description='Numeric Feature:',
    value=numeric_cols[0],
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

#visualize
widgets.interact(plot_numeric_box, df=widgets.fixed(player_game_df), col=dropdown_numeric)


print("Obbservations:")
print("game_id : not an important feature for analysis, can be dropped in future steps")
print("episode : distribution is starting from episode 7 until epiode 9, which is expected as the data was collected during that time period")
print("act : distribution is starting from act 1 until act 3, which is expected as the data was collected during that time period")
print("rounds_win : there are some negative values in the rounds_win column, which is not possible in the context of the game.Although there are high values nearly 18 rounds which is possible but we will need to investigate those records further to understand if they are valid or if they are data entry errors.")
print("round_loss : there are some negative values in the rounds_loss column, which is not possible in the context of the game. Although there are high values nearly 20 rounds which is possible but we will need to investigate those records further to understand if they are valid or if they are data entry errors.")
print("kills : there are some negative values in the kills column, which is not possible in the context of the game. Although there are high values nearly 35 kills which is possible")
print("assists : its not an important feature for analysis, can be dropped in future steps")
print("kdr : Some negative values in the kdr column, which is not possible in the context of the game")
print("avg_dmg_delta : There are some negative values which are not possible in the context of the game, but positive values are quite high but cant be verified as these calcualtions are not available in public domain")
print("headshot% : The range of headshot% is between 0 and 100, which is expected. ")
print("avg)dmg : There are some negative values which are not possible in the context of the game, but positive values are quite high but cant be verified as these calcualtions are not available in public domain")
print("acs : There are some negative values which are not possible in the context of the game, but positive values are quite high but cant be verified as these calcualtions are not available in public domain")
print("num_frag : this is correct as it is a count of the number of times a player was the first to get a kill in a round, which can be zero or more.")
# Out:
# Numeric columns: ['game_id', 'episode', 'act', 'round_wins', 'round_losses', 'kills', 'deaths', 'assists', 'kdr', 'avg_dmg_delta', 'headshot_pct', 'avg_dmg', 'acs', 'num_frag']
# interactive(children=(Dropdown(description='Numeric Feature:', layout=Layout(width='50%'), options=('game_id',…
# Obbservations:
# game_id : not an important feature for analysis, can be dropped in future steps
# episode : distribution is starting from episode 7 until epiode 9, which is expected as the data was collected during that time period
# act : distribution is starting from act 1 until act 3, which is expected as the data was collected during that time period
# rounds_win : there are some negative values in the rounds_win column, which is not possible in the context of the game.Although there are high values nearly 18 rounds which is possible but we will need to investigate those records further to understand if they are valid or if they are data entry errors.
# round_loss : there are some negative values in the rounds_loss column, which is not possible in the context of the game. Although there are high values nearly 20 rounds which is possible but we will need to investigate those records further to understand if they are valid or if they are data entry errors.
# kills : there are some negative values in the kills column, which is not possible in the context of the game. Although there are high values nearly 35 kills which is possible
# assists : its not an important feature for analysis, can be dropped in future steps
# kdr : Some negative values in the kdr column, which is not possible in the context of the game
# avg_dmg_delta : There are some negative values which are not possible in the context of the game, but positive values are quite high but cant be verified as these calcualtions are not available in public domain
# headshot% : The range of headshot% is between 0 and 100, which is expected.
# avg)dmg : There are some negative values which are not possible in the context of the game, but positive values are quite high but cant be verified as these calcualtions are not available in public domain
# acs : There are some negative values which are not possible in the context of the game, but positive values are quite high but cant be verified as these calcualtions are not available in public domain
# num_frag : this is correct as it is a count of the number of times a player was the first to get a kill in a round, which can be zero or more.

# %%
# ── Step 2C: Detect Anomalous Values (Categorical) ───────────────────────
# For categorical columns, we include both 'object' and 'string' data types to capture all potential categorical features.
# Exclude date columns - they will be type cast to datetime separately.
categorical_cols = [col for col in player_game_df.select_dtypes(include=['object', 'string']).columns.tolist()
                    if 'date' not in col.lower()]

# Create dropdown for categorical features
dropdown_cat = widgets.Dropdown(
    options=categorical_cols,
    description='Categorical/Date Feature:',
    value=categorical_cols[0],
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

#visualize
widgets.interact(plot_categorical_bottom, df=widgets.fixed(player_game_df), col=dropdown_cat, bottom_n=(20,1000,100))
# Out:
# interactive(children=(Dropdown(description='Categorical/Date Feature:', layout=Layout(width='50%'), options=('…
# <function src.utils.data_viz_utils.plot_categorical_bottom(df: pandas.core.frame.DataFrame, col: str, bottom_n=10)>

# %% [markdown]
# Step 2C: Statistical Summaries of Key Features: Generate descriptive statistics for numeric features and frequency counts for categorical features to understand central tendencies, variability, and common categories.

# %%
# ── Step 2C: Statistical Summaries — Match Outcome Anomalies ─────────────
print("Match Outcome Anomalies:")
# if there are any records where the match outcome is inconsistent with the expected outcome based on the player's performance metrics, it could indicate data entry errors or anomalies in the dataset. This can help identify potential issues with the data quality and ensure that the analysis is based on accurate and reliable information.
inconsistent_outcome = find_inconsistent_outcomes(player_game_df)
display(inconsistent_outcome)
# Out:
# Match Outcome Anomalies:
#       game_id  episode  act        rank        date      agent     map  \
# 26         27        6    2      Gold 1   4/22/2023     Cypher   Split
# 76         77        6    3      Gold 3    5/9/2023     Cypher    Bind
# 92         93        6    3      Gold 3   5/18/2023     Cypher   Split
# 127       128        6    3  Platinum 1   5/23/2023     Cypher   Lotus
# 307       308        7    1  Platinum 3   7/23/2023     Cypher    Bind
# ...       ...      ...  ...         ...         ...        ...     ...
# 1291     1740        6    2   Diamond 2  11/11/2024  Brimstone  Breeze
# 1292     1010        7    1  Platinum 1   3/11/2024       Omen  Sunset
# 1293     1495        6    2   Diamond 2   5/30/2023       Fade  Breeze
# 1294     1125        9    2  Platinum 1    5/4/2023      Viper   Lotus
# 1295     1820        7    3  Platinum 1  03/04/2026      KAY/O  Sunset
#
#       outcome  round_wins  round_losses  kills  deaths  assists  kdr  \
# 26       Draw          15            15     35      21        8  1.7
# 76       Draw          15            15     17      19        9  0.9
# 92       Draw          15            15     24      21        9  1.1
# 127      Draw          14            14     25      17        4  1.5
# 307      Draw          14            14     16      20        6  0.8
# ...       ...         ...           ...    ...     ...      ...  ...
# 1291     Draw           6             8     -2       7       10  1.0
# 1292     Draw          15             3     -2      13        5 -0.2
# 1293  Unknown           2            12     17      14        6  0.7
# 1294      NaN           7             3      6      13       10  0.8
# 1295      NaN          14            14      4      15        5  1.3
#
#       avg_dmg_delta  headshot_pct  avg_dmg  acs  num_frag        role
# 26               68            13      200  324         1    Sentinel
# 76               -2            19      115  173         4    Sentinel
# 92                6            12      144  223         1    Sentinel
# 127              35            13      152  243         1    Sentinel
# 307             -37            13      100  154         5    Sentinel
# ...             ...           ...      ...  ...       ...         ...
# 1291             17            77       13  266         7  Controller
# 1292             38             1      206   68         9  Controller
# 1293            -25            80      133  100         3   Initiator
# 1294            -30            52       73  216         4  Controller
# 1295            -48            50       68  147         9   Initiator
#
# [295 rows x 20 columns]

# %%
# ── Step 2C: Statistical Summaries — Numeric Anomalies ───────────────────
# Check for numeric anomalies in key performance metrics such as kills, deaths, round wins, round losses, and KDR.The values shouldn't be negative and should be within a reasonable range based on typical player performance. Identifying any outliers or unrealistic values can help ensure the integrity of the dataset and improve the accuracy of any subsequent analysis or modeling.
numeric_summary = numeric_anomaly_summary(
    player_game_df,
    ['kills','deaths','round_wins','round_losses','kdr']
)
print("Numeric Anomalies Summary:")
display(numeric_summary)
# Out:
# Numeric Anomalies Summary:
#         Feature  Negative Values  Zero Values  Outliers (>3σ)
# 0         kills               42            8               5
# 1        deaths               41            8              16
# 2    round_wins               42           15               0
# 3  round_losses               32           15               0
# 4           kdr               43            9              10

# %% [markdown]
# ## Step 2D: Label Encoding : Rank, Agent, Map

# %%
from sklearn.preprocessing import LabelEncoder

label_cols = ['rank', 'agent', 'map']
le = LabelEncoder()

df_label_encoded = player_game_df.copy()
label_mappings = {}

for col in label_cols:
    df_label_encoded[col] = le.fit_transform(player_game_df[col].astype(str))
    label_mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))

print("Label Encoding Mappings:\n")
for col, mapping in label_mappings.items():
    print(f"  {col}: {mapping}\n")

df_label_encoded[['rank', 'agent', 'map']].head(10)
# Out:
# Label Encoding Mappings:
#
#   rank: {'Ascendant 1': np.int64(0), 'Ascendant 2': np.int64(1), 'Diamond 1': np.int64(2), 'Diamond 2': np.int64(3), 'Diamond 3': np.int64(4), 'Gold 1': np.int64(5), 'Gold 2': np.int64(6), 'Gold 3': np.int64(7), 'Placement': np.int64(8), 'Platinum 1': np.int64(9), 'Platinum 2': np.int64(10), 'Platinum 3': np.int64(11), 'Silver 2': np.int64(12), 'Silver 3': np.int64(13), 'nan': np.int64(14)}
#
#   agent: {'Astra': np.int64(0), 'Breach': np.int64(1), 'Brimstone': np.int64(2), 'Cypher': np.int64(3), 'Fade': np.int64(4), 'KAY/O': np.int64(5), 'Killjoy': np.int64(6), 'Omen': np.int64(7), 'Phoenix': np.int64(8), 'UnknownAgent': np.int64(9), 'Viper': np.int64(10), 'Vyse': np.int64(11)}
#
#   map: {'Abyss': np.int64(0), 'Ascent': np.int64(1), 'Bind': np.int64(2), 'Breeze': np.int64(3), 'Fracture': np.int64(4), 'Haven': np.int64(5), 'Icebox': np.int64(6), 'Lotus': np.int64(7), 'Pearl': np.int64(8), 'Split': np.int64(9), 'Sunset': np.int64(10)}
#    rank  agent  map
# 0     8      3    1
# 1     8      3    6
# 2     8      5    7
# 3     8      2    1
# 4     8      3    5
# 5    12      5    5
# 6    12      3    8
# 7    12      5    6
# 8    12      3    8
# 9    12      8    4

# %%
# ── Step 2E: Statistical Summaries — Correlation Analysis ─────────────────
categorical_features = ['outcome', 'role']

# Drop date columns — they cannot be one-hot encoded or correlated numerically
date_cols = [col for col in df_label_encoded.columns if 'date' in col.lower()]
df_for_corr = df_label_encoded.drop(columns=date_cols)

# rank, agent, map are already label-encoded; one-hot encode remaining categoricals
df_encoded = pd.get_dummies(df_for_corr, columns=categorical_features, drop_first=True)

print("Correlation Matrix with All Features (Numeric & Label/One-Hot-Categorical):")
corr_matrix = df_encoded.corr()
print(corr_matrix.round(2)) 
plt.figure(figsize=(18, 14))
sns.heatmap(corr_matrix, cmap='Reds', annot=False, square=True)
plt.title("Correlation Matrix: Numeric & Encoded Categorical Features")
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix with All Features (Numeric & Label/One-Hot-Categorical):
#                  game_id  episode   act  rank  agent   map  round_wins  \
# game_id             1.00     0.39 -0.08 -0.12   0.29 -0.05       -0.30
# episode             0.39     1.00 -0.30 -0.46   0.13 -0.05       -0.03
# act                -0.08    -0.30  1.00 -0.04  -0.06 -0.00       -0.02
# rank               -0.12    -0.46 -0.04  1.00  -0.03  0.05       -0.06
# agent               0.29     0.13 -0.06 -0.03   1.00  0.03       -0.14
# map                -0.05    -0.05 -0.00  0.05   0.03  1.00        0.01
# round_wins         -0.30    -0.03 -0.02 -0.06  -0.14  0.01        1.00
# round_losses       -0.31    -0.00  0.03 -0.09  -0.06 -0.02       -0.06
# kills              -0.38    -0.02  0.00 -0.07  -0.12  0.02        0.40
# deaths             -0.39     0.00  0.01 -0.04  -0.06  0.02        0.12
# assists             0.03    -0.07  0.06  0.11  -0.04 -0.01        0.19
# kdr                -0.06    -0.03  0.04 -0.03  -0.01  0.02        0.21
# avg_dmg_delta      -0.10     0.01 -0.01 -0.04  -0.02  0.04        0.32
# headshot_pct        0.62     0.20 -0.05  0.01   0.20 -0.02       -0.25
# avg_dmg            -0.06     0.02  0.00 -0.01   0.04  0.06        0.12
# acs                -0.30    -0.01  0.01 -0.03  -0.11  0.00        0.21
# num_frag            0.33     0.04 -0.05  0.10   0.12 -0.03       -0.14
# outcome_Loss       -0.34     0.04  0.02 -0.08  -0.08  0.03       -0.30
# outcome_Unknown     0.46    -0.02 -0.03  0.06   0.13  0.02       -0.23
# outcome_Win        -0.37    -0.02 -0.01 -0.08  -0.15 -0.02        0.61
# role_Duelist        0.21    -0.01  0.07  0.06   0.23  0.04       -0.07
# role_Initiator      0.29    -0.06 -0.04  0.15  -0.10 -0.01       -0.16
# role_Sentinel      -0.62     0.01 -0.04 -0.16  -0.26  0.02        0.27
#
#                  round_losses  kills  deaths  ...  headshot_pct  avg_dmg  \
# game_id                 -0.31  -0.38   -0.39  ...          0.62    -0.06
# episode                 -0.00  -0.02    0.00  ...          0.20     0.02
# act                      0.03   0.00    0.01  ...         -0.05     0.00
# rank                    -0.09  -0.07   -0.04  ...          0.01    -0.01
# agent                   -0.06  -0.12   -0.06  ...          0.20     0.04
# map                     -0.02   0.02    0.02  ...         -0.02     0.06
# round_wins              -0.06   0.40    0.12  ...         -0.25     0.12
# round_losses             1.00   0.25    0.61  ...         -0.29    -0.02
# kills                    0.25   1.00    0.29  ...         -0.26     0.40
# deaths                   0.61   0.29    1.00  ...         -0.34    -0.02
# assists                  0.02   0.06    0.05  ...         -0.03     0.05
# kdr                     -0.29   0.35   -0.26  ...          0.03     0.31
# avg_dmg_delta           -0.22   0.50   -0.22  ...          0.01     0.54
# headshot_pct            -0.29  -0.26   -0.34  ...          1.00    -0.03
# avg_dmg                 -0.02   0.40   -0.02  ...         -0.03     1.00
# acs                      0.07   0.61    0.08  ...         -0.18     0.46
# num_frag                -0.16  -0.53   -0.17  ...          0.21    -0.27
# outcome_Loss             0.66   0.08    0.47  ...         -0.26    -0.07
# outcome_Unknown         -0.23  -0.21   -0.29  ...          0.30    -0.08
# outcome_Win             -0.33   0.30   -0.10  ...         -0.27     0.13
# role_Duelist            -0.10  -0.12   -0.08  ...          0.18     0.06
# role_Initiator          -0.13  -0.21   -0.18  ...          0.22    -0.03
# role_Sentinel            0.25   0.38    0.31  ...         -0.47     0.09
#
#                   acs  num_frag  outcome_Loss  outcome_Unknown  outcome_Win  \
# game_id         -0.30      0.33         -0.34             0.46        -0.37
# episode         -0.01      0.04          0.04            -0.02        -0.02
# act              0.01     -0.05          0.02            -0.03        -0.01
# rank            -0.03      0.10         -0.08             0.06        -0.08
# agent           -0.11      0.12         -0.08             0.13        -0.15
# map              0.00     -0.03          0.03             0.02        -0.02
# round_wins       0.21     -0.14         -0.30            -0.23         0.61
# round_losses     0.07     -0.16          0.66            -0.23        -0.33
# kills            0.61     -0.53          0.08            -0.21         0.30
# deaths           0.08     -0.17          0.47            -0.29        -0.10
# assists         -0.01      0.07         -0.18             0.06         0.09
# kdr              0.46     -0.27         -0.27            -0.05         0.35
# avg_dmg_delta    0.60     -0.36         -0.30            -0.08         0.42
# headshot_pct    -0.18      0.21         -0.26             0.30        -0.27
# avg_dmg          0.46     -0.27         -0.07            -0.08         0.13
# acs              1.00     -0.50          0.04            -0.21         0.27
# num_frag        -0.50      1.00         -0.20             0.20        -0.14
# outcome_Loss     0.04     -0.20          1.00            -0.23        -0.62
# outcome_Unknown -0.21      0.20         -0.23             1.00        -0.23
# outcome_Win      0.27     -0.14         -0.62            -0.23         1.00
# role_Duelist    -0.10      0.02         -0.11             0.09        -0.09
# role_Initiator  -0.17      0.17         -0.17             0.22        -0.17
# role_Sentinel    0.29     -0.33          0.30            -0.37         0.32
#
#                  role_Duelist  role_Initiator  role_Sentinel
# game_id                  0.21            0.29          -0.62
# episode                 -0.01           -0.06           0.01
# act                      0.07           -0.04          -0.04
# rank                     0.06            0.15          -0.16
# agent                    0.23           -0.10          -0.26
# map                      0.04           -0.01           0.02
# round_wins              -0.07           -0.16           0.27
# round_losses            -0.10           -0.13           0.25
# kills                   -0.12           -0.21           0.38
# deaths                  -0.08           -0.18           0.31
# assists                  0.02            0.09          -0.17
# kdr                      0.03           -0.08           0.08
# avg_dmg_delta           -0.02           -0.11           0.14
# headshot_pct             0.18            0.22          -0.47
# avg_dmg                  0.06           -0.03           0.09
# acs                     -0.10           -0.17           0.29
# num_frag                 0.02            0.17          -0.33
# outcome_Loss            -0.11           -0.17           0.30
# outcome_Unknown          0.09            0.22          -0.37
# outcome_Win             -0.09           -0.17           0.32
# role_Duelist             1.00           -0.04          -0.26
# role_Initiator          -0.04            1.00          -0.52
# role_Sentinel           -0.26           -0.52           1.00
#
# [23 rows x 23 columns]
